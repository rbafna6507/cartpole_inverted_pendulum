# %% [markdown]
# # State PPO starter
# Upload cartpole_sim_vision.zip. Defaults are provisional; read README. Simulation only.

# %%
from google.colab import files
files.upload()
import zipfile
zipfile.ZipFile("cartpole_sim_vision.zip").extractall("/content")
# %cd /content/cartpole_sim_vision
# %pip install -r requirements-sim.txt

# %%
# !python train_state.py --smoke --out results/smoke

# %%
# !python train_state.py --task balance --steps 1000000 --out results/balance

# %%
# !python evaluate.py results/balance --episodes 30 --html
from IPython.display import HTML, display
display(HTML(open("results/balance_replay.html").read()))

# %%
import shutil
shutil.make_archive("training_results", "zip", "results")
files.download("training_results.zip")
